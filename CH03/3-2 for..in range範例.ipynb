# %%
total = 0
for i in range(1, 101):
  total += i
print('total =', total)
# Out:
# total = 5050

# %%
total = 0
for i in range(2, 101):
  total += i
print('total =', total)
# Out:
# total = 5049

# %%
total = 0
for i in range(1, 100):
  total += i
print('total =', total)
# Out:
# total = 4950

# %%
print('B10906021高柏翰')
# Out:
# B10906021高柏翰
