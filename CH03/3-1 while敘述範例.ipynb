# %%
i = 1
total = 0
while i <= 100:
  total += i
  i += 1
print('total = ', total)
# Out:
# total =  5050

# %%
i = 2
total = 0
while i <= 100:
  total += i
  i += 1
print('total = ', total)
# Out:
# total =  5049

# %%
i = 1
total = 0
while i < 100:
  total += i
  i += 1
print('total = ', total)
# Out:
# total =  4950

# %%
i = 1
total = 0
while i <= 100:
  total += i
  i += 2
print('total = ', total)
# Out:
# total =  2500

# %%
print('B10906021高柏翰')
# Out:
# B10906021高柏翰
