# %%
a = 123
b = 123.456
c = 'Python'

print('|%5d|'%(a))
print('|%10.2f|'%(b))
print('|%10s|'%(c))
print()

print('|%-5d|'%(a))
print('|%-10.2f|'%(b))
print('|%-10s|'%(c))
# Out:
# |  123|
# |    123.46|
# |    Python|
#
# |123  |
# |123.46    |
# |Python    |

# %%
print('B10906021高柏翰')
# Out:
# B10906021高柏翰
