# %%
import math
r , height =eval(input())
area = math.pi * (r ** 2)
volume = area * height
print('area:',format(area,'5.2f'),',','volume:',format(volume,'5.2f'))
# Out:
# 6.5, 10
# area: 132.73 , volume: 1327.32

# %%
print('B10906021高柏翰')
# Out:
# B10906021高柏翰
