# %%
v, a = eval(input())
length = (v**2)/(2*a)
print('Minimum runway length is',format(length, '5.2f'),'meters')
# Out:
# 70, 4.3
# Minimum runway length is 569.77 meters

# %%
print('B10906021高柏翰')
# Out:
# B10906021高柏翰
