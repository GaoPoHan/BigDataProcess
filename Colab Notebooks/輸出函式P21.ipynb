# %%
print('Python\"Kotlin')
print('Python\'Kotlin')
print('Python\\Kotlin')
print('Python\tKotlin')
print('Python\nKotlin')


print('B10906021高柏翰')
# Out:
# Python"Kotlin
# Python'Kotlin
# Python\Kotlin
# Python	Kotlin
# Python
# Kotlin
# B10906021高柏翰
