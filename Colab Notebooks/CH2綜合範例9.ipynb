# %%
x = eval(input())
y = eval(input())
dist = ((x-5)**2 + (y-6)**2)**0.5

if dist <= 15:
  print('Inside')
else:
  print('Outside')
# Out:
# 7
# 20
# Inside

# %%
x = eval(input())
y = eval(input())
dist = ((x-5)**2 + (y-6)**2)**0.5

if dist <= 15:
  print('Inside')
else:
  print('Outside')
# Out:
# 30
# 35
# Outside

# %%
print('B10906021高柏翰')
# Out:
# B10906021高柏翰
