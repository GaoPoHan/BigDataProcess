# %%
f=eval(input('Enter Fahrenheit=? '))
c=(f-32)*5/9
print('Fahrenheit',(format(f, '5.2f')),'- - ->','Celsius',(format(c, '5.2f')))
# Out:
# Enter Fahrenheit=? 212
# Fahrenheit 212.00 - - -> Celsius 100.00

# %%
print('B10906021高柏翰')
# Out:
# B10906021高柏翰
