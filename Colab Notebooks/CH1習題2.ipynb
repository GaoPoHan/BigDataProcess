# %%
import math
r =eval(input())
s = 2 * r * math.sin(math.pi/5)
area = (5 * s**2) / (4 * math.tan(math.pi/5))
print('Area is',format(area, '5.2f'))
# Out:
# 5.5
# Area is 71.92

# %%
print('B10906021高柏翰')
# Out:
# B10906021高柏翰
