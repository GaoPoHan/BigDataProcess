# %%
num1, num2, num3 = eval(input('Enter thrre integers: '))
if num1 > num2:
  num1, num2 = num2, num1

if num2 > num3:
  num2, num3 = num3, num2

if num1 > num2:
  num1, num2 = num2, num1

print('The sorted numbers are', num1, num2, num3)
# Out:
# Enter thrre integers: 8, 6, 1
# The sorted numbers are 1 6 8
