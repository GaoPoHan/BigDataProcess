# %%
import math
math.sin(0)
# Out:
# 0.0

# %%
math.sin(math.pi/2)
# Out:
# 1.0

# %%
math.cos(math.pi/2)
# Out:
# 6.123233995736766e-17

# %%
math.cos(0)
# Out:
# 1.0

# %%
print('B10906021高柏翰')
# Out:
# B10906021高柏翰
