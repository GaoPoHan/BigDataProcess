# %%
import random
num = random.randint(1, 100)
if num % 2 == 0:
  print('d% is even number.'%(num))
else:
  print('d% is odd number.'%(num))
# Out:
# d 37s odd number.

# %%
import random
num = random.randint(1, 100)
if num % 2 == 0:
  print('d% is even number.'%(num))
else:
  print('d% is odd number.'%(num))
# Out:
# d 50s even number.

# %%
print('B10906021高柏翰')
# Out:
# B10906021高柏翰
