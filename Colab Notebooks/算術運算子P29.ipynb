# %%
a = 100
b = a / 3
print(b)
c = a // 3
print(c)
f = a % 3
print(f)
d = a ** 2
print(d)
e = a ** 0.5
print(e)
print('B10906021高柏翰')
# Out:
# 33.333333333333336
# 33
# 1
# 10000
# 10.0
# B10906021高柏翰

# %%
area = 3.14159 * r ** 2
perimeter = 2 * 3.15159
