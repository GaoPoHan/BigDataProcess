# %%
a = eval(input())

while a != 0:
  print(a % 10, end = '')
  a //= 10
# Out:
# 31283
# 38213

# %%
a = eval(input())

while a != 0:
  print(a % 10, end = '')
  a //= 10
# Out:
# 1003120
# 0213001

# %%
print('B10906021高柏翰')
# Out:
# B10906021高柏翰
