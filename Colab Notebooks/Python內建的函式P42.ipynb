# %%
abs(-100)
# Out:
# 100

# %%
max(22, 33, 11, 88, 99, 66)
# Out:
# 99

# %%
min(22, 33, 11, 88, 99, 66)
# Out:
# 11

# %%
pow(2, 10)
# Out:
# 1024

# %%
round(5.6)
# Out:
# 6

# %%
round(5.2)
# Out:
# 5

# %%
round(4.6)
# Out:
# 5

# %%
round(4.5)
# Out:
# 4

# %%
round(123.456, 2)
# Out:
# 123.46

# %%
round(123.456, 1)
# Out:
# 123.5

# %%
print('B10906021高柏翰')
# Out:
# B10906021高柏翰
