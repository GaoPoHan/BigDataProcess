# %%
import math
r = 100
area = math.pi * r ** 2
perimeter = 2 * math.pi * r
print(area)
print(perimeter)
# Out:
# 31415.926535897932
# 628.3185307179587

# %%
print('B10906021高柏翰')
# Out:
# B10906021高柏翰
