# %%
c = input()

if ('a' <= c <= 'z') or ('A' <= c <= 'Z'):
  print(c, 'is ans alphabet.')
elif ('0' <= c <= '9'):
  print(c, 'is a number.')
else:
  print(c, 'is a symbol.')
# Out:
# P
# P is ans alphabet.

# %%
c = input()

if ('a' <= c <= 'z') or ('A' <= c <= 'Z'):
  print(c, 'is ans alphabet.')
elif ('0' <= c <= '9'):
  print(c, 'is a number.')
else:
  print(c, 'is a symbol.')
# Out:
# @
# @ is a symbol.

# %%
c = input()

if ('a' <= c <= 'z') or ('A' <= c <= 'Z'):
  print(c, 'is ans alphabet.')
elif ('0' <= c <= '9'):
  print(c, 'is a number.')
else:
  print(c, 'is a symbol.')
# Out:
# 7
# 7 is a number.

# %%
print('B10906021高柏翰')
# Out:
# B10906021高柏翰
