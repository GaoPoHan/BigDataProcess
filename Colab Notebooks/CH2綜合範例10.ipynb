# %%
side1 = eval(input())
side2 = eval(input())
side3 = eval(input())

if side1+side2 > side3 and side2+side3 > side1 and side1+side3 >side2:
  print(side1+side2+side3)
else:
  print('Invalid')
# Out:
# 5
# 6
# 13
# Invalid

# %%
side1 = eval(input())
side2 = eval(input())
side3 = eval(input())

if side1+side2 > side3 and side2+side3 > side1 and side1+side3 >side2:
  print(side1+side2+side3)
else:
  print('Invalid')
# Out:
# 1
# 1
# 1
# 3

# %%
print('B10906021高柏翰')
# Out:
# B10906021高柏翰
