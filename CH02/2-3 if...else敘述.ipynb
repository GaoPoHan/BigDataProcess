# %%
a = eval(input('Enter a number: '))
if a > 0:
  print(a, 'is greater than 0')
else:
  print(a, 'is less than 0')
print('over')
# Out:
# Enter a number: 100
# 100 is greater than 0
# over

# %%
print('B10906021高柏翰')
# Out:
# B10906021高柏翰
